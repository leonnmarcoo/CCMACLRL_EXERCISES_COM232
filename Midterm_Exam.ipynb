# %% [markdown]
# <a href="https://colab.research.google.com/github/leonnmarcoo/CCMACLRL_EXERCISES_COM232/blob/main/Midterm_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr
import statsmodels.api as sm
import numpy as np

# %% [markdown]
# ## Training Data

# %%
dataset_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/ebd51da1dafde093c18d9e8f35c834d91b2887f7/datasets/train.csv?raw=true'
df = pd.read_csv(dataset_url)
df.head()
# Out:
#    id  MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0   0                 5                   8                5              8
# 1   1                 6                   7                4              4
# 2   2                 6                   5                6              7
# 3   3                 3                   4                6              5
# 4   4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
# ...

# %% [markdown]
# ### Scatter Plot

# %%
plt.scatter(df["MonsoonIntensity"],
            df["FloodProbability"])
plt.xlabel("MonsoonIntensity")
plt.ylabel("FloodProbability")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df["TopographyDrainage"],
            df["FloodProbability"])
plt.xlabel("TopographyDrainage")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["RiverManagement"],
            df["FloodProbability"])
plt.xlabel("RiverManagement")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["Deforestation"],
            df["FloodProbability"])
plt.xlabel("Deforestation")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["Urbanization"],
            df["FloodProbability"])
plt.xlabel("Urbanization")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["ClimateChange"],
            df["FloodProbability"])
plt.xlabel("ClimateChange")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["DamsQuality"],
            df["FloodProbability"])
plt.xlabel("DamsQuality")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["Siltation"],
            df["FloodProbability"])
plt.xlabel("Siltation")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["AgriculturalPractices"],
            df["FloodProbability"])
plt.xlabel("AgriculturalPractices")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["Encroachments"],
            df["FloodProbability"])
plt.xlabel("Encroachments")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["IneffectiveDisasterPreparedness"],
            df["FloodProbability"])
plt.xlabel("IneffectiveDisasterPreparedness")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["DrainageSystems"],
            df["FloodProbability"])
plt.xlabel("DrainageSystems")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["CoastalVulnerability"],
            df["FloodProbability"])
plt.xlabel("CoastalVulnerability")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["Landslides"],
            df["FloodProbability"])
plt.xlabel("Landslides")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["Watersheds"],
            df["FloodProbability"])
plt.xlabel("Watersheds")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["DeterioratingInfrastructure"],
            df["FloodProbability"])
plt.xlabel("DeterioratingInfrastructure")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["PopulationScore"],
            df["FloodProbability"])
plt.xlabel("PopulationScore")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["WetlandLoss"],
            df["FloodProbability"])
plt.xlabel("WetlandLoss")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["InadequatePlanning"],
            df["FloodProbability"])
plt.xlabel("InadequatePlanning")
plt.ylabel("FloodProbability")
plt.show()

# %%
plt.scatter(df["PoliticalFactors"],
            df["FloodProbability"])
plt.xlabel("PoliticalFactors")
plt.ylabel("FloodProbability")
plt.show()

# %% [markdown]
# ### Pairplot

# %%
fig, ax = plt.subplots(5,5, figsize=(10,10))

ax[0, 0].scatter(df["MonsoonIntensity"], df["FloodProbability"])
ax[0, 1].scatter(df["TopographyDrainage"], df["FloodProbability"])
ax[1, 0].scatter(df["RiverManagement"], df["FloodProbability"])
ax[1, 1].scatter(df["Deforestation"], df["FloodProbability"])
ax[2, 0].scatter(df["Urbanization"], df["FloodProbability"])
ax[2, 1].scatter(df["ClimateChange"], df["FloodProbability"])
ax[3, 0].scatter(df["DamsQuality"], df["FloodProbability"])
ax[3, 1].scatter(df["Siltation"], df["FloodProbability"])
ax[4, 0].scatter(df["AgriculturalPractices"], df["FloodProbability"])
ax[4, 1].scatter(df["Encroachments"], df["FloodProbability"])
ax[0, 2].scatter(df["IneffectiveDisasterPreparedness"], df["FloodProbability"])
ax[0, 3].scatter(df["DrainageSystems"], df["FloodProbability"])
ax[1, 2].scatter(df["CoastalVulnerability"], df["FloodProbability"])
ax[1, 3].scatter(df["Landslides"], df["FloodProbability"])
ax[2, 2].scatter(df["Watersheds"], df["FloodProbability"])
ax[2, 3].scatter(df["DeterioratingInfrastructure"], df["FloodProbability"])
ax[3, 2].scatter(df["PopulationScore"], df["FloodProbability"])
ax[3, 3].scatter(df["WetlandLoss"], df["FloodProbability"])
ax[4, 2].scatter(df["InadequatePlanning"], df["FloodProbability"])
ax[4, 3].scatter(df["PoliticalFactors"], df["FloodProbability"])

# %% [markdown]
# ## Test File

# %%
test_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/ebd51da1dafde093c18d9e8f35c834d91b2887f7/datasets/test.csv?raw=true'
testdata = pd.read_csv(test_url)

# %% [markdown]
# ## Sample Submission File

# %%
sample_submission_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/ebd51da1dafde093c18d9e8f35c834d91b2887f7/datasets/sample_submission.csv?raw=true'

samplefile = pd.read_csv(sample_submission_url)

id = samplefile.pop('id')
y_pred = model.predict(testdata)

# Create a submission DataFrame
submission_df = pd.DataFrame({
    'id': id,
    'FloodProbability': y_pred
})

# Save the submission DataFrame to a CSV file
submission_df.to_csv('submission_file.csv', index=False)
print("Submission file created: submission_file.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2419836664.py in <cell line: 0>()
#       4
#       5 id = samplefile.pop('id')
# ----> 6 y_pred = model.predict(testdata)
#       7
#       8 # Create a submission DataFrame
#
# NameError: name 'model' is not defined
